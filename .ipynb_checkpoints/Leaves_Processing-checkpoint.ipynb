# %%
from spectral import *
import cv2
import os
import glob
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from time import time
import re

# %%
def load_one_img(hdr_file, bil_file):
    img = envi.open(hdr_file, bil_file)
    array = img.load()
    return np.array(array)

# %%
bands_file = 'C:/Data Processing/wave_length.txt'

bands = pd.read_csv(bands_file, header=None)
wavelength = bands[0].tolist()

# %%
bands_str = [str(item) for item in wavelength]

# %%
root_dir = "D:/Leaf_Project/08_01_2025/"
# filename = "Pathes.txt"
trainName ="train.txt"
testName ="test.txt"

# %%
def get_file_list(filename):
    pathes = []
    with open(filename, 'r') as file:
        lines = [line.strip() for line in file if line.strip()]
        for line in lines:
            full_path = root_dir + line + "/calibrations"
            pathes.append(full_path)

    return pathes

# %%
train_list = get_file_list(trainName)
train_list
# Out:
# ['D:/Leaf_Project/08_01_2025/Chai_H1_G0-2_20_2025-07-30_18-07-33/calibrations',
#  'D:/Leaf_Project/08_01_2025/Chai_H1_G0-2_9_2025-07-30_17-47-09/calibrations',
#  'D:/Leaf_Project/08_01_2025/Chai_2H1-G0-3-7_2025-07-31_18-33-25/calibrations',
#  'D:/Leaf_Project/08_01_2025/Chai_H1_G0-2_8_2025-07-30_17-45-16/calibrations',
#  'D:/Leaf_Project/08_01_2025/Chai_H1_G0-2_17_2025-07-30_18-01-38/calibrations',
#  'D:/Leaf_Project/08_01_2025/Chai_2H1-G0-3-4_2025-07-31_18-28-56/calibrations',
#  'D:/Leaf_Project/08_01_2025/Chai_H1-G0-3-15_2025-08-01_15-19-45/calibrations',
#  'D:/Leaf_Project/08_01_2025/Chai_H1-G0-3-25_2025-08-01_15-39-13/calibrations',
#  'D:/Leaf_Project/08_01_2025/Chai_G6-3-1_2025-07-30_18-14-46/calibrations',
#  'D:/Leaf_Project/08_01_2025/Chai_G6-3-5_2025-07-30_18-21-09/calibrations',
#  'D:/Leaf_Project/08_01_2025/Chai_G6-3-15_2025-07-30_18-34-26/calibrations',
#  'D:/Leaf_Project/08_01_2025/Chai_G6-3-18_2025-07-30_18-38-19/calibrations',
#  'D:/Leaf_Project/08_01_2025/Chai_G6-3-22_2025-07-30_18-43-35/calibrations',
#  'D:/Leaf_Project/08_01_2025/Chai_G6-1-1_2025-07-30_18-48-58/calibrations',
#  'D:/Leaf_Project/08_01_2025/Chai_G6-1-5_2025-07-30_18-54-22/calibrations',
#  'D:/Leaf_Project/08_01_2025/Chai_G6-1-15_2025-07-30_19-08-11/calibrations']

# %%
test_list = get_file_list(testName)
test_list
# Out:
# ['D:/Leaf_Project/08_01_2025/Chai_G6-3-11_2025-07-30_18-29-13/calibrations',
#  'D:/Leaf_Project/08_01_2025/Chai_H1-G0-3-22_2025-08-01_15-33-25/calibrations',
#  'D:/Leaf_Project/08_01_2025/Chai_G6-1-10_2025-07-30_19-01-02/calibrations',
#  'D:/Leaf_Project/08_01_2025/Chai_H1_G0-2_3_2025-07-30_17-34-55/calibrations']

# %%
# str = 'D:/Leaf_Project/09_09_2025/G0H_016_2025-09-10_21-02-42/calibrations'
# new_str = str[27:].split('_')[0]
# new_str

# %%
def get_pathes(path_list):
    pattern = r"G\d+"
    all_files = []
    for path in path_list:
        sub_pathes = []
        d_file = path + "/Dark.txt"
        w_file = path + "/White.txt"
        bip_file = glob.glob(path + "/*FromSelection.bip")
        hdr_file = bip_file[0] + ".hdr"
        label = re.search(pattern, path)
        sub_pathes.extend([d_file, w_file, hdr_file, bip_file[0],label.group()])
        all_files.append(sub_pathes)
        
    return all_files

# %%
def get_img_vals(pathes):
    vals = []
    for files in pathes:
        dark = pd.read_csv(files[0], header=None, sep='\t')
        white = pd.read_csv(files[1], header=None, sep='\t')
        dark_np = dark[1].to_numpy()
        white_np = white[1].to_numpy()
        cube = load_one_img(files[2], files[3])
        val = (cube - dark_np)/(white_np - dark_np + 0.0001)
        vals.append([val, files[4]])
    return vals

# %%
train_path = get_pathes(train_list)
train_path[0]
# Out:
# ['D:/Leaf_Project/08_01_2025/Chai_H1_G0-2_20_2025-07-30_18-07-33/calibrations/Dark.txt',
#  'D:/Leaf_Project/08_01_2025/Chai_H1_G0-2_20_2025-07-30_18-07-33/calibrations/White.txt',
#  'D:/Leaf_Project/08_01_2025/Chai_H1_G0-2_20_2025-07-30_18-07-33/calibrations\\Chai_H1_G0-2_20-FromSelection.bip.hdr',
#  'D:/Leaf_Project/08_01_2025/Chai_H1_G0-2_20_2025-07-30_18-07-33/calibrations\\Chai_H1_G0-2_20-FromSelection.bip',
#  'G0']

# %%
train_vals = get_img_vals(train_path)

# %%
len(train_vals)
# Out:
# 16

# %%
test_path = get_pathes(test_list)
test_path
# Out:
# [['D:/Leaf_Project/08_01_2025/Chai_G6-3-11_2025-07-30_18-29-13/calibrations/Dark.txt',
#   'D:/Leaf_Project/08_01_2025/Chai_G6-3-11_2025-07-30_18-29-13/calibrations/White.txt',
#   'D:/Leaf_Project/08_01_2025/Chai_G6-3-11_2025-07-30_18-29-13/calibrations\\Chai_G6-3-11-FromSelection.bip.hdr',
#   'D:/Leaf_Project/08_01_2025/Chai_G6-3-11_2025-07-30_18-29-13/calibrations\\Chai_G6-3-11-FromSelection.bip',
#   'G6'],
#  ['D:/Leaf_Project/08_01_2025/Chai_H1-G0-3-22_2025-08-01_15-33-25/calibrations/Dark.txt',
#   'D:/Leaf_Project/08_01_2025/Chai_H1-G0-3-22_2025-08-01_15-33-25/calibrations/White.txt',
#   'D:/Leaf_Project/08_01_2025/Chai_H1-G0-3-22_2025-08-01_15-33-25/calibrations\\Chai_H1-G0-3-22_2025-08-01_15-33-25-FromSelection-FromSelection.bip.hdr',
#   'D:/Leaf_Project/08_01_2025/Chai_H1-G0-3-22_2025-08-01_15-33-25/calibrations\\Chai_H1-G0-3-22_2025-08-01_15-33-25-FromSelection-FromSelection.bip',
#   'G0'],
#  ['D:/Leaf_Project/08_01_2025/Chai_G6-1-10_2025-07-30_19-01-02/calibrations/Dark.txt',
#   'D:/Leaf_Project/08_01_2025/Chai_G6-1-10_2025-07-30_19-01-02/calibrations/White.txt',
#   'D:/Leaf_Project/08_01_2025/Chai_G6-1-10_2025-07-30_19-01-02/calibrations\\Chai_G6-1-10-FromSelection.bip.hdr',
#   'D:/Leaf_Project/08_01_2025/Chai_G6-1-10_2025-07-30_19-01-02/calibrations\\Chai_G6-1-10-FromSelection.bip',
#   'G6'],
#  ['D:/Leaf_Project/08_01_2025/Chai_H1_G0-2_3_2025-07-30_17-34-55/calibrations/Dark.txt',
#   'D:/Leaf_Project/08_01_2025/Chai_H1_G0-2_3_2025-07-30_17-34-55/calibrations/White.txt',
#   'D:/Leaf_Project/08_01_2025/Chai_H1_G0-2_3_2025-07-30_17-34-55/calibrations\\Chai_H1_G0-2_3-FromSelection.bip.hdr',
#   'D:/Leaf_Project/08_01_2025/Chai_H1_G0-2_3_2025-07-30_17-34-55/calibrations\\Chai_H1_G0-2_3-FromSelection.bip',
#   'G0']]

# %%
test_vals = get_img_vals(test_path)

# %%
def convert_pd(np_list):
    pd_list = []
    for arr in np_list:
        reshaped_np = arr[0].reshape(-1, 448)
        _label = arr[1]
        _pd = pd.DataFrame(data = reshaped_np, columns=bands_str)
        _pd['label1'] = int(_label[1])  # 'G0H', 'G1',...
        if(_label == 'G0'):
            _pd['label2'] = 0
        else:
            _pd['label2'] = 1

        pd_list.append(_pd)

    final_df = pd.concat(pd_list, ignore_index=True)

    scaler = MinMaxScaler()
    final_df[bands_str] = scaler.fit_transform(final_df[bands_str])
    return final_df

# %%
train_pd = convert_pd(train_vals)

# %%
test_pd = convert_pd(test_vals)

# %%
train_pd
# Out:
#            397.01    398.32    399.63    400.93    402.24    403.55    404.86  \
# 0        0.232314  0.232314  0.183099  0.446429  0.284617  0.306122  0.278690
# 1        0.232320  0.232320  0.211268  0.375000  0.261539  0.224490  0.278690
# 2        0.232320  0.232320  0.239437  0.357143  0.253847  0.306122  0.278695
# 3        0.232323  0.232323  0.253521  0.321429  0.215383  0.244898  0.278695
# 4        0.232334  0.232334  0.295775  0.303571  0.300003  0.571429  0.278693
# ...           ...       ...       ...       ...       ...       ...       ...
# 1453868  0.232325  0.232325  0.246479  0.321429  0.153846  0.285713  0.278684
# 1453869  0.232324  0.232324  0.274650  0.285714  0.184615  0.306122  0.278689
# 1453870  0.232324  0.232324  0.281692  0.357143  0.246154  0.336736  0.278697
# 1453871  0.232328  0.232328  0.281692  0.392857  0.292308  0.326532  0.278700
# 1453872  0.232326  0.232326  0.253522  0.392857  0.292308  0.346941  0.278713
#
#            406.17    407.48    408.79  ...    994.65    996.06    997.47  \
# 0        0.300000  0.228576  0.457627  ...  0.182795  0.103875  0.133709
# 1        0.357143  0.228571  0.355932  ...  0.199338  0.103875  0.186440
# 2        0.328571  0.228576  0.457627  ...  0.156327  0.090670  0.137476
# 3        0.400000  0.228584  0.457627  ...  0.189413  0.093311  0.182674
# 4        0.228571  0.228560  0.457627  ...  0.172870  0.101234  0.178907
# ...           ...       ...       ...  ...       ...       ...       ...
# 1453868  0.307145  0.228576  0.338983  ...  0.280399  0.369718  0.228816
# 1453869  0.300001  0.228580  0.406780  ...  0.263030  0.345070  0.231640
# 1453870  0.292858  0.228584  0.440678  ...  0.250623  0.348592  0.237290
# 1453871  0.235713  0.228560  0.338983  ...  0.198513  0.239437  0.163843
# 1453872  0.271429  0.228564  0.423729  ...  0.220846  0.260563  0.163843
#
#            998.88   1000.29    1001.7   1003.11   1004.52  label1  label2
# 0        0.087737  0.137931  0.131604  0.131604  0.131604       0       0
# 1        0.082077  0.187739  0.204611  0.204611  0.204611       0       0
# 2        0.104719  0.164751  0.127761  0.127761  0.131604       0       0
# 3        0.130190  0.199234  0.177713  0.177713  0.177713       0       0
# 4        0.082077  0.145594  0.181556  0.181556  0.181556       0       0
# ...           ...       ...       ...       ...       ...     ...     ...
# 1453868  0.339623  0.253834  0.250723  0.250723  0.250723       6       1
# 1453869  0.328302  0.253834  0.247841  0.247841  0.247841       6       1
# 1453870  0.294340  0.210730  0.184440  0.184440  0.184440       6       1
# 1453871  0.256604  0.210730  0.187322  0.187322  0.187322       6       1
# 1453872  0.260377  0.199236  0.175794  0.175794  0.175794       6       1
#
# [1453873 rows x 450 columns]

# %%
# G0_files = get_file_list("G0.txt")
# G1_files = get_file_list("G1.txt")
# G3_files = get_file_list("G3.txt")
# G4_files = get_file_list("G4.txt")
# G6_files = get_file_list("G6.txt")

# %%
# G0_files[-1:]

# %%
# G0_train_vals = get_img_vals(get_pathes(G0_files[:-1]))
# G0_test_vals = get_img_vals(get_pathes(G0_files[-1:]))

# G1_train_vals = get_img_vals(get_pathes(G1_files[:-1]))
# G1_test_vals = get_img_vals(get_pathes(G1_files[-1:]))

# G3_train_vals = get_img_vals(get_pathes(G3_files[:-1]))
# G3_test_vals = get_img_vals(get_pathes(G3_files[-1:]))

# G4_train_vals = get_img_vals(get_pathes(G4_files[:-1]))
# G4_test_vals = get_img_vals(get_pathes(G4_files[-1:]))

# G6_train_vals = get_img_vals(get_pathes(G6_files[:-1]))
# G6_test_vals = get_img_vals(get_pathes(G6_files[-1:]))

# %%
# G0_pd_train = convert_pd(G0_train_vals)
# G0_pd_test = convert_pd(G0_test_vals)

# G1_pd_train = convert_pd(G1_train_vals)
# G1_pd_test = convert_pd(G1_test_vals)

# G3_pd_train = convert_pd(G3_train_vals)
# G3_pd_test = convert_pd(G3_test_vals)

# G4_pd_train = convert_pd(G4_train_vals)
# G4_pd_test = convert_pd(G4_test_vals)

# G6_pd_train = convert_pd(G6_train_vals)
# G6_pd_test = convert_pd(G6_test_vals)

# %%
from sklearn.model_selection import train_test_split
#from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RepeatedKFold

from sklearn.model_selection import cross_val_score
from sklearn.feature_selection import SelectKBest,f_classif,chi2

#from sklearn.datasets import make_moons, make_circles, make_classification
from sklearn.neural_network import MLPClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.gaussian_process.kernels import RBF
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis

from sklearn.ensemble import StackingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import SGDClassifier

from sklearn.ensemble import ExtraTreesClassifier
from sklearn.feature_selection import SelectFromModel

from sklearn.feature_selection import RFECV

import xgboost as xgb
from sklearn.metrics import accuracy_score, f1_score, classification_report

# %%
# final_train

# %%
# # train_lst = [G1_pd_train, G3_pd_train, G4_pd_train, G6_pd_train]
# # test_lst = [G1_pd_test, G3_pd_test, G4_pd_test, G6_pd_test]

# train_lst = [ G3_pd_train, G4_pd_train, G6_pd_train]
# test_lst = [ G3_pd_test, G4_pd_test, G6_pd_test]

# count = 1
# G1_pd_train['label2'] = 0
# G1_pd_test['label2'] = 0

# for train, test in zip(train_lst, test_lst):
#     train_pd_lst = [G1_pd_train]
#     test_pd_lst = [G1_pd_test]
#     train_pd_lst.append(train)
#     test_pd_lst.append(test)
#     final_train = pd.concat(train_pd_lst, ignore_index=True)
#     final_test = pd.concat(test_pd_lst, ignore_index=True)
#     train_random = final_train.sample(frac=1, random_state=42).reset_index(drop=True)
#     test_random = final_test.sample(frac=1, random_state=42).reset_index(drop=True)
    
#     X_train = train_random.drop(columns=['label1', 'label2'])  # All columns except 'label'
#     # Only the 'label' column
#     y2_train = train_random['label2']

#     X_test = test_random.drop(columns=['label1', 'label2'])  # All columns except 'label'
#     y2_test = test_random['label2']
#     # 3. Initialize the Classifier
#     # Note: If you have only 2 classes, you don't strictly need 'num_class' 
#     # or 'multi:softmax', but this config works safely for 3+ classes too.
#     # for label 1
#     model = xgb.XGBClassifier(
#         objective='binary:logistic',  # Use 'binary:logistic' if strictly 2 classes
#         # num_class= len(y2_train.unique()),  # Automatically set number of classes
#         tree_method="hist",         # Required for modern GPU support
#         device="cuda",              # Activates NVIDIA GPU
#         eval_metric='mlogloss'
#     )
    
#     # 4. Train the model
#     print("Current: 0 V.S.", count)
#     count+=1
#     print("Training started...")
#     model.fit(X_train, y2_train)
#     print("Training complete!")

#     # 5. Make Predictions
#     predictions = model.predict(X_test)
    
#     # 6. Check Accuracy
#     acc = accuracy_score(y2_test, predictions)
#     print(f"Accuracy: {acc * 100:.2f}%")
    
#     # 7. Detailed Report
#     # This shows precision, recall, and f1-score for each class
#     print("\nClassification Report:")
#     print(classification_report(y2_test, predictions))

# %%
train_pd['label2'].min()
# Out:
# 0

# %%
# Shuffle 100% of the rows (frac=1)
train_random = train_pd.sample(frac=1, random_state=42).reset_index(drop=True)

# %%
train_random
# Out:
#            397.01    398.32    399.63    400.93    402.24    403.55    404.86  \
# 0        0.232325  0.232325  0.253522  0.339286  0.215385  0.326531  0.278689
# 1        0.232319  0.232321  0.253521  0.321429  0.384615  0.428571  0.278695
# 2        0.232330  0.232330  0.352113  0.401791  0.415385  0.428571  0.278689
# 3        0.232326  0.232326  0.338028  0.375000  0.400000  0.377555  0.278711
# 4        0.232326  0.232326  0.295775  0.348217  0.315388  0.387755  0.278689
# ...           ...       ...       ...       ...       ...       ...       ...
# 1453868  0.232330  0.232330  0.267606  0.410714  0.307692  0.346939  0.409836
# 1453869  0.232328  0.232328  0.316905  0.321429  0.307692  0.448987  0.278695
# 1453870  0.232324  0.232324  0.309859  0.428571  0.323077  0.387755  0.278702
# 1453871  0.232327  0.232327  0.253521  0.392857  0.353846  0.612245  0.278700
# 1453872  0.232331  0.232331  0.436620  0.571429  0.415385  0.510204  0.278700
#
#            406.17    407.48    408.79  ...    994.65    996.06    997.47  \
# 0        0.278572  0.228579  0.406782  ...  0.302732  0.411972  0.404896
# 1        0.357143  0.228574  0.423729  ...  0.359805  0.362679  0.506591
# 2        0.342857  0.228580  0.322034  ...  0.305214  0.288735  0.427495
# 3        0.371434  0.228579  0.432207  ...  0.543429  0.774648  0.550852
# 4        0.328571  0.228576  0.389831  ...  0.188587  0.250000  0.273069
# ...           ...       ...       ...  ...       ...       ...       ...
# 1453868  0.371429  0.228591  0.525424  ...  0.337472  0.365320  0.355935
# 1453869  0.278572  0.228571  0.525424  ...  0.426803  0.549296  0.387009
# 1453870  0.357143  0.300000  0.525424  ...  0.307695  0.433099  0.412429
# 1453871  0.328571  0.228582  0.542373  ...  0.530190  0.475352  0.347461
# 1453872  0.385714  0.314286  0.305085  ...  0.374693  0.531690  0.510358
#
#            998.88   1000.29    1001.7   1003.11   1004.52  label1  label2
# 0        0.388679  0.383142  0.288187  0.288187  0.288187       6       1
# 1        0.342456  0.540230  0.508165  0.508165  0.508165       6       1
# 2        0.285852  0.425287  0.415946  0.415946  0.415946       6       1
# 3        0.709434  0.592917  0.590783  0.590783  0.590783       6       1
# 4        0.245283  0.279693  0.269932  0.269932  0.269932       0       0
# ...           ...       ...       ...       ...       ...     ...     ...
# 1453868  0.449057  0.486590  0.465898  0.462055  0.462055       0       0
# 1453869  0.554717  0.423376  0.426517  0.426517  0.426517       6       1
# 1453870  0.288682  0.429119  0.291069  0.291069  0.291069       0       0
# 1453871  0.353777  0.544061  0.546590  0.546590  0.546590       0       0
# 1453872  0.342456  0.505747  0.389052  0.389052  0.389052       0       0
#
# [1453873 rows x 450 columns]

# %%
test_random = test_pd.sample(frac=1, random_state=42).reset_index(drop=True)

# %%
_label1 = test_random['label1'].to_numpy()

count = np.count_nonzero(_label1 == 1)
count
# Out:
# 0

# %%
# 1. Separate Features (X) and Target (y)
X_train = train_random.drop(columns=['label1', 'label2'])  # All columns except 'label'
y1_train = train_random['label1']                 # Only the 'label' column
y2_train = train_random['label2']

X_test = test_random.drop(columns=['label1', 'label2'])  # All columns except 'label'
y1_test = test_random['label1']                 # Only the 'label' column
y2_test = test_random['label2']

# %%
train_random['label2'].min()
# Out:
# 0

# %%
from sklearn.preprocessing import LabelEncoder

# 1. Initialize the encoder
le = LabelEncoder()

# 2. Fit and Transform your labels
# This maps: 0->0, 1->1, 3->2, 4->3, 6->4
y_train = le.fit_transform(y1_train)
y_test  = le.fit_transform(y1_test)

# %%
# 3. Initialize the Classifier
# Note: If you have only 2 classes, you don't strictly need 'num_class' 
# or 'multi:softmax', but this config works safely for 3+ classes too.
# for label 1
model = xgb.XGBClassifier(
    objective='multi:softmax',  # Use 'binary:logistic' if strictly 2 classes
    num_class= 5, #len(y.unique()),  # Automatically set number of classes
    tree_method="hist",         # Required for modern GPU support
    device="cuda",              # Activates NVIDIA GPU
    eval_metric='mlogloss'
)

# 4. Train the model
print("Training started...")
model.fit(X_train, y_train)
print("Training complete!")
# Out:
# Training started...
# Training complete!

# %%
# 5. Make Predictions
predictions = model.predict(X_test)

# 6. Check Accuracy
acc = accuracy_score(y_test, predictions)
print(f"Accuracy: {acc * 100:.2f}%")

# 7. Detailed Report
# This shows precision, recall, and f1-score for each class
print("\nClassification Report:")
print(classification_report(y_test, predictions))
# Out:
# Accuracy: 39.30%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00    253668
#            1       0.43      0.81      0.56    241290
#
#     accuracy                           0.39    494958
#    macro avg       0.22      0.40      0.28    494958
# weighted avg       0.21      0.39      0.28    494958

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

# Generate confusion matrix
cm = confusion_matrix(y_test, predictions)

# Visualize it
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=le.classes_)
disp.plot()
plt.show()

# %%
# 3. Initialize the Classifier
# Note: If you have only 2 classes, you don't strictly need 'num_class' 
# or 'multi:softmax', but this config works safely for 3+ classes too.
# for label 1
model = xgb.XGBClassifier(
    objective='binary:logistic',  # Use 'binary:logistic' if strictly 2 classes
    # num_class= len(y2_train.unique()),  # Automatically set number of classes
    tree_method="hist",         # Required for modern GPU support
    device="cuda",              # Activates NVIDIA GPU
    eval_metric='mlogloss'
)

# 4. Train the model
print("Training started...")
model.fit(X_train, y2_train)
print("Training complete!")
# Out:
# Training started...
# Training complete!

# %%
# 5. Make Predictions
predictions = model.predict(X_test)

# 6. Check Accuracy
acc = accuracy_score(y_test, predictions)
print(f"Accuracy: {acc * 100:.2f}%")

# 7. Detailed Report
# This shows precision, recall, and f1-score for each class
print("\nClassification Report:")
print(classification_report(y2_test, predictions))
# Out:
# Accuracy: 35.96%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.41      0.57      0.48    253668
#            1       0.23      0.14      0.17    241290
#
#     accuracy                           0.36    494958
#    macro avg       0.32      0.35      0.32    494958
# weighted avg       0.32      0.36      0.33    494958

# %%
estimators = [
    ('QuadraticDiscriminantAnalysis',QuadraticDiscriminantAnalysis()),
    ('RandomForestClassifier', RandomForestClassifier(n_estimators=10, random_state=42)),
    ('KNeighborsClassifier',KNeighborsClassifier(n_neighbors=3)),
    ('GaussianNB',GaussianNB()),
    ('AdaBoostClassifier',AdaBoostClassifier()),
    ('DecisionTreeClassifier',DecisionTreeClassifier()),
    #('SVC', SVC()),
]

# %%
for item in estimators:
    name = item[0]
    clf  = item[1]
    t0 = time()
    clf = clf.fit(X_train, y_train)
    
    # Make predictions on the test set
    y_pred = clf.predict(X_test)
    _score = accuracy_score(y_test,y_pred)

    # Evaluate the classification performance
    #print(classification_report(y_test, y_pred))
    print("Model {} get {}".format(name, _score))

    
    print("using {} seconds".format(time()-t0))
# Out:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# Cell In[128], line 5
#       3 clf  = item[1]
#       4 t0 = time()
# ----> 5 clf = clf.fit(X_train, y_train)
#       7 # Make predictions on the test set
#       8 y_pred = clf.predict(X_test)
#
# File ~\CodingEnvironment\Python\Lib\site-packages\sklearn\base.py:1336, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1329     estimator._validate_params()
#    1331 with config_context(
#    1332     skip_parameter_validation=(
#    1333         prefer_skip_nested_validation or global_skip_validation
#    1334     )
#    1335 ):
# -> 1336     return fit_method(estimator, *args, **kwargs)
#
# File ~\CodingEnvironment\Python\Lib\site-packages\sklearn\discriminant_analysis.py:1132, in QuadraticDiscriminantAnalysis.fit(self, X, y)
#    1130     else:
#    1131         msg_param = "shrinkage" if self.solver == "eigen" else "reg_param"
# -> 1132         raise linalg.LinAlgError(
#    1133             f"The covariance matrix of class {class_label} is not full "
#    1134             f"rank. Increase the value of `{msg_param}` to reduce the "
#    1135             f"collinearity.",
#    1136         )
#    1138 cov.append(cov_class)
#    1139 scalings.append(scaling_class)
#
# LinAlgError: The covariance matrix of class 0 is not full rank. Increase the value of `reg_param` to reduce the collinearity.
